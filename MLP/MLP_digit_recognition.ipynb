# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.datasets import mnist

# %%
# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# compute num of labels
num_labels = len(np.unique(y_train))

print(num_labels)
# Out:
# 10

# %%
# convert to one-hot vector
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# image dims (assumed square)
image_size = x_train.shape[1]
input_size = image_size * image_size

# %%
# re-size and normalize
x_train = np.reshape(x_train, [-1, input_size])
x_train = x_train.astype('float32') / 255
x_test = np.reshape(x_test, [-1, input_size])
x_test = x_test.astype('float32') / 255

# %%
# network params
batch_size = 128
hidden_units = 256
dropout = 0.45

# %%
# model is a 3-layer MLP with ReLU and dropout after each layer
model = Sequential()
model.add(Dense(hidden_units, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(hidden_units))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
plot_model(model, to_file = 'mlp-mnist.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               200960
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 10)                2570
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# loss function for one-hot vector
# use of adam optimizer
# accuracy is good metric for clf tasks.
model.compile(loss='categorical_crossentropy', 
              optimizer = 'adam', 
              metrics = ['accuracy'])

# trian the network
model.fit(x_train, y_train, epochs = 100, batch_size=batch_size)

# validate the model on test dataset to determine generalization
_, acc = model.evaluate(x_test, 
                        y_test, 
                        batch_size=batch_size, 
                        verbose=0)

print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# Epoch 1/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4174 - accuracy: 0.8727
# Epoch 2/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1935 - accuracy: 0.9418
# Epoch 3/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1531 - accuracy: 0.9540
# Epoch 4/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1304 - accuracy: 0.9612
# Epoch 5/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1150 - accuracy: 0.9642
# Epoch 6/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1017 - accuracy: 0.9692
# Epoch 7/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0946 - accuracy: 0.9711
# Epoch 8/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0887 - accuracy: 0.9729
# Epoch 9/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0827 - accuracy: 0.9738
# Epoch 10/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0776 - accuracy: 0.9755
# Epoch 11/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0739 - accuracy: 0.9768
# Epoch 12/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0736 - accuracy: 0.9769
# Epoch 13/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0680 - accuracy: 0.9779
# Epoch 14/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0661 - accuracy: 0.9788
# Epoch 15/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0609 - accuracy: 0.9804
# Epoch 16/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0607 - accuracy: 0.9807
# Epoch 17/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0588 - accuracy: 0.9811
# Epoch 18/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0568 - accuracy: 0.9808
# Epoch 19/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0566 - accuracy: 0.9822
# Epoch 20/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0534 - accuracy: 0.9830
# Epoch 21/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0525 - accuracy: 0.9830
# Epoch 22/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0527 - accuracy: 0.9829
# Epoch 23/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0484 - accuracy: 0.9846
# Epoch 24/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0472 - accuracy: 0.9852
# Epoch 25/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0486 - accuracy: 0.9843
# Epoch 26/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0459 - accuracy: 0.9847
# Epoch 27/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0464 - accuracy: 0.9853
# Epoch 28/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0462 - accuracy: 0.9849
# Epoch 29/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0462 - accuracy: 0.9850
# Epoch 30/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0431 - accuracy: 0.9859
# Epoch 31/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0440 - accuracy: 0.9857
# Epoch 32/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0424 - accuracy: 0.9865
# Epoch 33/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0389 - accuracy: 0.9870
# Epoch 34/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0423 - accuracy: 0.9863
# Epoch 35/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0431 - accuracy: 0.9862
# Epoch 36/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0393 - accuracy: 0.9870
# Epoch 37/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0372 - accuracy: 0.9874
# Epoch 38/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0415 - accuracy: 0.9868
# Epoch 39/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0380 - accuracy: 0.9874
# Epoch 40/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0365 - accuracy: 0.9881
# Epoch 41/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0359 - accuracy: 0.9882
# Epoch 42/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0366 - accuracy: 0.9883
# Epoch 43/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0389 - accuracy: 0.9878
# Epoch 44/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0343 - accuracy: 0.9887
# Epoch 45/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0376 - accuracy: 0.9883
# Epoch 46/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0348 - accuracy: 0.9888
# Epoch 47/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0354 - accuracy: 0.9883
# Epoch 48/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0352 - accuracy: 0.9885
# Epoch 49/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0363 - accuracy: 0.9885
# Epoch 50/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0325 - accuracy: 0.9896
# Epoch 51/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0349 - accuracy: 0.9885
# Epoch 52/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0342 - accuracy: 0.9893
# Epoch 53/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0325 - accuracy: 0.9897
# Epoch 54/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0334 - accuracy: 0.9890
# Epoch 55/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0322 - accuracy: 0.9898
# Epoch 56/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9888
# Epoch 57/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0308 - accuracy: 0.9898
# Epoch 58/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0311 - accuracy: 0.9899
# Epoch 59/100
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0328 - accuracy: 0.9900
# Epoch 60/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0317 - accuracy: 0.9896
# Epoch 61/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0323 - accuracy: 0.9901
# Epoch 62/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0294 - accuracy: 0.9903
# Epoch 63/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0301 - accuracy: 0.9906
# Epoch 64/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0308 - accuracy: 0.9905
# Epoch 65/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0299 - accuracy: 0.9901
# Epoch 66/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0296 - accuracy: 0.9908
# Epoch 67/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0293 - accuracy: 0.9909
# Epoch 68/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0293 - accuracy: 0.9907
# Epoch 69/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0299 - accuracy: 0.9902
# Epoch 70/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0328 - accuracy: 0.9899
# Epoch 71/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0297 - accuracy: 0.9905
# Epoch 72/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0321 - accuracy: 0.9898
# Epoch 73/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0277 - accuracy: 0.9915
# Epoch 74/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0304 - accuracy: 0.9900
# Epoch 75/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0289 - accuracy: 0.9909
# Epoch 76/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0266 - accuracy: 0.9913
# Epoch 77/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0276 - accuracy: 0.9912
# Epoch 78/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0263 - accuracy: 0.9912
# Epoch 79/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0296 - accuracy: 0.9909
# Epoch 80/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0241 - accuracy: 0.9926
# Epoch 81/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0297 - accuracy: 0.9907
# Epoch 82/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0290 - accuracy: 0.9909
# Epoch 83/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0267 - accuracy: 0.9910
# Epoch 84/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0283 - accuracy: 0.9911
# Epoch 85/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0292 - accuracy: 0.9909
# Epoch 86/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0289 - accuracy: 0.9911
# Epoch 87/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0267 - accuracy: 0.9916
# Epoch 88/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0264 - accuracy: 0.9916
# Epoch 89/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0280 - accuracy: 0.9915
# Epoch 90/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0284 - accuracy: 0.9913
# Epoch 91/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0246 - accuracy: 0.9925
# Epoch 92/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0260 - accuracy: 0.9916
# Epoch 93/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0293 - accuracy: 0.9912
# Epoch 94/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0280 - accuracy: 0.9916
# Epoch 95/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0231 - accuracy: 0.9927
# Epoch 96/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0265 - accuracy: 0.9916
# Epoch 97/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0271 - accuracy: 0.9918
# Epoch 98/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0274 - accuracy: 0.9918
# Epoch 99/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0237 - accuracy: 0.9932
# Epoch 100/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0238 - accuracy: 0.9929
#
# Test accuracy: 98.5%
